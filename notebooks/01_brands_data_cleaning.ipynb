# %%
import pandas as pd

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 1000)

# %%
# orders_qu.csv
url = "https://drive.google.com/file/d/1kvYPlqcaKuBpHStyaNSchBYIb2iTuEji/view?usp=drive_link"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
orders = pd.read_csv(path)

# orderlines_qu.csv
url = "https://drive.google.com/file/d/1krfmZrcb92ZYPXu32fD6i6OA-_LQpVfo/view?usp=drive_link"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
orderlines = pd.read_csv(path)

# brands_cl.csv
url = "https://drive.google.com/file/d/1XGyabaa4mAkjixMk3XPgx_14OoSse3rs/view?usp=drive_link"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
brands = pd.read_csv(path)

# products_cl.csv
url = "https://drive.google.com/file/d/1IPnKYLSnrST0HBZMeSeNrhFfWU31QvwB/view?usp=drive_link"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
products = pd.read_csv(path)

# %%
orders_df = orders.copy()
orderlines_df = orderlines.copy()
brands_df = brands.copy()
products_df = products.copy()

# %%
brands_df
# Out:
#     short              long
# 0     8MO         8Mobility
# 1     ACM              Acme
# 2     ADN            Adonit
# 3     AII             Aiino
# 4     AKI            Akitio
# 5     ALL         Allocacoc
# 6     AP2             Apple
# 7     APP             Apple
# 8     BAN        Band&Strap
# 9     BEA             Beats
# 10    BEL            Belkin
# 11    BEZ             Be.ez
# 12    BLL        BlueLounge
# 13    BLM  Blue Microphones
# 14    BNQ              BenQ
# 15    BOD        BodyGuardz
# 16    BOO              Booq
# 17    BOS              Bose
# 18    BTC         Boostcase
# 19    CAD              Bose
# 20    CAI          Casetify
# 21    CEL             Celly
# 22    COG            Cogito
# 23    CRU           Crucial
# 24    CYB        Cyberpower
# 25    CYG           Cygnett
# 26    DEV            Devolo
# 27    DJI               DJI
# 28    DLK            D-Link
# 29    DLL              Dell
# 30    DOD          Dodocool
# 31    DRO             Drobo
# ...

# %%
brands_df.isna().sum()
# Out:
# short    0
# long     0
# dtype: int64

# %%
brands_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
brands_df["short"].duplicated().sum()
# Out:
# np.int64(0)

# %%
brands_df["long"].duplicated().sum()
# Out:
# np.int64(4)

# %%
brands_df.loc[(brands_df["long"].duplicated())]
# Out:
#     short      long
# 7     APP     Apple
# 19    CAD      Bose
# 80    LIB   Unknown
# 153   STA  Startech

# %%
brands_df.loc[(brands_df["long"].duplicated(keep=False))].sort_values(by="long")
# Out:
#     short      long
# 6     AP2     Apple
# 7     APP     Apple
# 17    BOS      Bose
# 19    CAD      Bose
# 117   OTR  Startech
# 153   STA  Startech
# 37    ENV   Unknown
# 80    LIB   Unknown

# %%
products_df.head()
# Out:
#        sku                                           name  \
# 0  RAI0007              Silver Rain Design mStand Support
# 1  APP0023              Apple Mac Keyboard Keypad Spanish
# 2  APP0025               Mighty Mouse Apple Mouse for Mac
# 3  APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4  KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
#
#                                                             desc  price  \
# 0                   Aluminum support compatible with all MacBook  59.99
# 1                      USB ultrathin keyboard Apple Mac Spanish.  59.00
# 2                                         mouse Apple USB cable.  59.00
# 3                          IPhone dock and USB Cable Apple iPod.  25.00
# 4  2GB RAM Mac mini and iMac (2006/07) MacBook Pro (2006/07/08).  34.99
#
#    in_stock      type
# 0         1      8696
# 1         0  13855401
# 2         0      1387
# 3         0      1230
# 4         1      1364

# %%
products_df["sku"].str[:3].head()
# Out:
# 0    RAI
# 1    APP
# 2    APP
# 3    APP
# 4    KIN
# Name: sku, dtype: object

# %%
products_df.loc[: , ["short"]] = products_df["sku"].str[:3]
products_df.head()
# Out:
#        sku                                           name  \
# 0  RAI0007              Silver Rain Design mStand Support
# 1  APP0023              Apple Mac Keyboard Keypad Spanish
# 2  APP0025               Mighty Mouse Apple Mouse for Mac
# 3  APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4  KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
#
#                                                             desc  price  \
# 0                   Aluminum support compatible with all MacBook  59.99
# 1                      USB ultrathin keyboard Apple Mac Spanish.  59.00
# 2                                         mouse Apple USB cable.  59.00
# 3                          IPhone dock and USB Cable Apple iPod.  25.00
# 4  2GB RAM Mac mini and iMac (2006/07) MacBook Pro (2006/07/08).  34.99
#
#    in_stock      type short
# 0         1      8696   RAI
# 1         0  13855401   APP
# 2         0      1387   APP
# 3         0      1230   APP
# 4         1      1364   KIN

# %%
pbm = products_df.merge(brands_df, on="short", how="left")
pbm.head()
# Out:
#        sku                                           name  \
# 0  RAI0007              Silver Rain Design mStand Support
# 1  APP0023              Apple Mac Keyboard Keypad Spanish
# 2  APP0025               Mighty Mouse Apple Mouse for Mac
# 3  APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4  KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
#
#                                                             desc  price  \
# 0                   Aluminum support compatible with all MacBook  59.99
# 1                      USB ultrathin keyboard Apple Mac Spanish.  59.00
# 2                                         mouse Apple USB cable.  59.00
# 3                          IPhone dock and USB Cable Apple iPod.  25.00
# 4  2GB RAM Mac mini and iMac (2006/07) MacBook Pro (2006/07/08).  34.99
#
#    in_stock      type short         long
# 0         1      8696   RAI  Rain Design
# 1         0  13855401   APP        Apple
# 2         0      1387   APP        Apple
# ...

# %%
brands_df.loc[(brands_df["long"].duplicated(keep=False))].sort_values(by="long")
# Out:
#     short      long
# 6     AP2     Apple
# 7     APP     Apple
# 17    BOS      Bose
# 19    CAD      Bose
# 117   OTR  Startech
# 153   STA  Startech
# 37    ENV   Unknown
# 80    LIB   Unknown

# %%
pbm.loc[pbm["short"] == "APP", :].shape[0]
# Out:
# 1721

# %%
pbm.loc[pbm["short"] == "AP2", :]#.shape[0]
# Out:
#           sku  \
# 1172  AP20102
# 2964  AP20104
# 2965  AP20105
# 2980  AP20147
# 4051  AP20111
# 4052  AP20106
# 4055  AP20107
# 4059  AP20110
# 4061  AP20109
# 4212  AP20101
# 6710  AP20021
# 6715  AP20023
# 6716  AP20025
# 6719  AP20028
# 7051  AP20085
# 7052  AP20079
# 7054  AP20080
# 7056  AP20081
# 7057  AP20083
# 7058  AP20084
# 7079  AP20016
# 7082  AP20093
# 7083  AP20094
# 7084  AP20089
# 7085  AP20096
# 7086  AP20097
# 7087  AP20098
# 7088  AP20099
# 7089  AP20113
# 7090  AP20090
# 7091  AP20091
# 7092  AP20087
# 7093  AP20088
# 7094  AP20092
# 7109  AP20160
# 7110  AP20100
# 7113  AP20108
# 7115  AP20146
# 7116  AP20148
# 7117  AP20159
# 7118  AP20156
# 7119  AP20157
# 7120  AP20392
# 7121  AP20155
# 7126  AP20103
# 7127  AP20132
# 7128  AP20163
# 7129  AP20165
# 7130  AP20177
# 7131  AP20166
# 7132  AP20167
# 7133  AP20169
# 7134  AP20178
# 7135  AP20170
# 7136  AP20179
# 7137  AP20189
# 7138  AP20180
# 7139  AP20190
# 7140  AP20182
# 7141  AP20171
# 7142  AP20183
# ...

# %%
pbm.loc[pbm["short"] == "MUJ", :]#.shape[0]
# Out:
#             sku  \
# 336     MUJ0009
# 924     MUJ0007
# 5020    MUJ0012
# 5021    MUJ0013
# 5022    MUJ0014
# 5023    MUJ0020
# 5024    MUJ0021
# 5119    MUJ0024
# 5140    MUJ0016
# 5143    MUJ0017
# 5144    MUJ0023
# 5151    MUJ0019
# 5433    MUJ0018
# 5434    MUJ0025
# 5435    MUJ0015
# 5436    MUJ0022
# 6404    MUJ0031
# 6408    MUJ0032
# 6410    MUJ0026
# 6411    MUJ0027
# 6412    MUJ0030
# 6413    MUJ0029
# 6414    MUJ0028
# 6935  MUJ0018-A
# 8178    MUJ0033
# 8179    MUJ0035
# 8180    MUJ0036
# 8181    MUJ0037
# 8182    MUJ0038
# 8183    MUJ0040
# 8184    MUJ0041
# 8185    MUJ0042
# 8186    MUJ0039
# 8190    MUJ0034
# 8880  MUJ0010-A
# 9411  MUJ0028-A
#
#                                                                     name  \
# 336      Mujjo Touchscreen Gloves iPhone iPad and iPod Gray (Size M / L)
# 924     Mujjo Touchscreen Gloves iPhone iPad and iPod Black (Size S / M)
# 5020                    Mujjo Leather Wallet Leather Case Tan iPhone 7/8
# ...

# %%
brands_df.loc[brands_df["short"] == "MUJ", "long"] = "Mujjo"

# %%
brands_df.loc[brands_df["short"] == "MUJ", :]
# Out:
#    short   long
# 98   MUJ  Mujjo

# %%
pbm.loc[pbm["short"] == "MOP", :]#.shape[0]
# Out:
#             sku  \
# 25      MOP0011
# 57      MOP0013
# 360     MOP0027
# 590     MOP0031
# 591     MOP0033
# 685     MOP0034
# 686     MOP0035
# 687     MOP0036
# 688     MOP0037
# 754     MOP0046
# 755     MOP0047
# 807     MOP0053
# 808     MOP0055
# 825     MOP0056
# 1790    MOP0060
# 1797    MOP0061
# 1801    MOP0062
# 1802    MOP0063
# 1803    MOP0064
# 1804    MOP0065
# 1805    MOP0066
# 1806    MOP0067
# 1869    MOP0069
# 2876    MOP0070
# 2899    MOP0071
# 3555    MOP0073
# 4175    MOP0076
# 4179    MOP0077
# 4182    MOP0078
# 4185    MOP0079
# 4186    MOP0075
# 4271    MOP0021
# 4273    MOP0054
# 4598    MOP0080
# 4599    MOP0081
# 4600    MOP0082
# 4601    MOP0083
# 4602    MOP0084
# 4603    MOP0085
# 4604    MOP0086
# 4605    MOP0087
# 4606    MOP0072
# 4607    MOP0088
# 4809    MOP0089
# 4810    MOP0090
# 5440    MOP0074
# 5712  MOP0058-A
# 5753    MOP0091
# 5773    MOP0095
# 5774    MOP0094
# 5775    MOP0093
# 5782    MOP0096
# 5783    MOP0097
# 5784    MOP0098
# ...

# %%
pbm.loc[pbm["short"] == "JYB", :]#.shape[0]
# Out:
#           sku                                         name  \
# 8105  JYB0007  X3 Jaybird Wireless Bluetooth Headset Black
# 8106  JYB0008     Jaybird Freedom Bluetooth Headphones Red
# 8107  JYB0009   Jaybird Freedom Bluetooth Headphones White
# 8108  JYB0010   Jaybird Freedom Bluetooth Headphones Black
#
#                                                                                                          desc  \
# 8105  In-ear headphones waterproof and wireless 8 hours of autonomous iPhone iPad iPod powder and Apple Watch
# 8106        In-ear headphones small metallic design Bluetooth connection for iPhone iPad iPod and Apple Watch
# 8107        In-ear headphones small metallic design Bluetooth connection for iPhone iPad iPod and Apple Watch
# 8108        In-ear headphones small metallic design Bluetooth connection for iPhone iPad iPod and Apple Watch
#
#        price  in_stock  type short     long
# 8105  129.00         0  5384   JYB  Jaybird
# ...

# %%
pbm.loc[pbm["short"] == "KEN", :]#.shape[0]
# Out:
#             sku  \
# 40      KEN0028
# 85      KEN0045
# 86      KEN0046
# 194     KEN0059
# 195     KEN0062
# 196     KEN0063
# 318     KEN0064
# 338     KEN0078
# 339     KEN0079
# 341     KEN0080
# 342     KEN0081
# 346     KEN0093
# 347     KEN0094
# 366     KEN0096
# 392     KEN0105
# 496     KEN0109
# 497     KEN0110
# 498     KEN0111
# 577     KEN0129
# 731     KEN0166
# 780     KEN0172
# 782     KEN0171
# 799     KEN0174
# 804     KEN0175
# 854     KEN0179
# 1230    KEN0194
# 1354    KEN0196
# 1392    KEN0206
# 1393    KEN0209
# 1410    KEN0208
# 1420    KEN0195
# 1436    KEN0200
# 1458    KEN0211
# 1475    KEN0204
# 1527    KEN0201
# 1586    KEN0207
# 1823    KEN0212
# 2072    KEN0210
# 2267    KEN0218
# 2289  KEN0203-A
# 2388    KEN0220
# 2390    KEN0223
# 2391    KEN0224
# 2392    KEN0225
# 2394    KEN0227
# 2396    KEN0226
# 3006    KEN0230
# 3008    KEN0229
# 3163    KEN0232
# 3630    KEN0235
# 3653    KEN0234
# 3764    KEN0236
# 3832    KEN0237
# 4547    KEN0240
# ...

# %%
brands_df.loc[brands_df["short"] == "KEN", "long"] = "Kensington"

# %%
brands_df.loc[brands_df["short"] == "KEN", :]
# Out:
#    short        long
# 70   KEN  Kensington

# %%
pbm.loc[pbm["short"] == "CAD", :].shape[0]
# Out:
# 0

# %%
pbm.loc[pbm["short"] == "ENV", :].shape[0]
# Out:
# 0

# %%
pbm.loc[pbm["short"] == "LIB", :].shape[0]
# Out:
# 0

# %%
pbm.loc[pbm["short"] == "STA", :]#.shape[0]
# Out:
#             sku  \
# 793     STA0016
# 923     STA0013
# 1583    STA0009
# 1592    STA0017
# 1595    STA0018
# 1814    STA0020
# 1821    STA0011
# 1936    STA0019
# 2104    STA0008
# 2166    STA0030
# 2199    STA0021
# 2316    STA0022
# 2323    STA0023
# 2324    STA0024
# 2325    STA0025
# 2326    STA0026
# 2327    STA0027
# 2328    STA0028
# 2329    STA0029
# 2330    STA0031
# 3800  STA0010-A
# 5780    STA0032
# 5781    STA0033
# 6059    STA0034
# 6060    STA0035
# 6061    STA0036
# 6062  STA0031-A
# 6063    STA0038
# 6064    STA0042
# 6065    STA0039
# 6069    STA0040
# 6070    STA0041
# 6082    STA0048
# 6083    STA0060
# 6084    STA0050
# 6085    STA0047
# 6086    STA0054
# 6087    STA0051
# 6089    STA0049
# 6090    STA0061
# 6092    STA0053
# 6093    STA0062
# 6094    STA0063
# 6102    STA0043
# 6103    STA0044
# 6104    STA0045
# 6110    STA0046
# 6111    STA0052
# 6112    STA0058
# 6113    STA0059
# 6119    STA0055
# 6121    STA0056
# 6122    STA0057
# 6244  STA0039-A
# ...

# %%
pbm.loc[pbm["short"] == "OTR", :]#.shape[0]
# Out:
#             sku  \
# 82      OTR0045
# 276     OTR0062
# 281     OTR0039
# 692     OTR0103
# 693     OTR0104
# 694     OTR0107
# 928     OTR0075
# 929     OTR0092
# 932     OTR0031
# 1414    OTR0120
# 1455    OTR0119
# 2098    OTR0124
# 3299  OTR0039-A
# 4557    OTR0130
# 5708  OTR0025-A
#
#                                                                  name  \
# 82            External Slim Case for SuperDrive MacBook / MacBook Pro
# 276                           StarTech USB adapter mini Bluetooth 2.1
# 281                            Startech Splitter Adapter 2 headphones
# 692                    Grenade Grip Gopole EmpuÌ ± Adura GoPro camera
# 693              Xsories Big U-Shot GoPro Camera Extension 95cm Black
# 694                 Xsories 50cm extension U-Shot camera GoPro Silver
# 928                            Startech Ethernet Cable Cat6 10m Black
# 929                            StarTech HDMI Extension Cable 2m Black
# ...

# %%
pbm.loc[pbm["type"] == "12995397", :]#.shape[0]
# Out:
#             sku  \
# 17      HGD0007
# 82      OTR0045
# 133     DLK0011
# 134     DLK0012
# 148     NTE0011
# 166     OWC0037
# 271     NTE0025
# 272     NTE0026
# 312     LMP0011
# 367     HGD0018
# 413     NTE0049
# 414     NTE0050
# 468     NTE0053
# 594     WDT0206
# 642     SNN0027
# 752     SNN0030
# 756     SNN0032
# 894     LAN0009
# 1219    KAN0036
# 1393    KEN0209
# 1410    KEN0208
# 1663    LMP0016
# 1685    BEL0181
# 1788    MAC0102
# 2071    OWC0144
# 2121    GTE0049
# 2180    OWC0145
# 2187    LAN0014
# 2370    SNN0050
# 2438    GTE0053
# 3024    WDT0310
# 3113    TRA0040
# 3299  OTR0039-A
# 3338    KAN0049
# 3551    OWC0160
# 3960    MAC0122
# 3967    MAC0123
# 4205    WDT0325
# 4297    WDT0324
# 4549    KEN0242
# 4739    KEN0228
# 4740    MAC0126
# 4818    LMP0021
# 4929    LAC0194
# 4940    GTE0068
# 4953    GTE0078
# 5318  HGD0001-A
# 5469    OWC0190
# 5477    OWC0201
# 5481  DRB0019-A
# 5855    SAT0018
# 5856    SAT0019
# 5858    OWC0214
# 5859    OWC0215
# ...

# %%
pbm.loc[pbm["sku"] == "OTR0045", :]
# Out:
#         sku                                                     name  \
# 82  OTR0045  External Slim Case for SuperDrive MacBook / MacBook Pro
#
#                                                      desc  price  in_stock  \
# 82  External SuperDrive case for MacBook and MacBook Pro.   35.0         1
#
#         type short      long
# 82  12995397   OTR  Startech

# %%
pbm.loc[pbm["sku"] == "STA0045", :]
# Out:
#           sku  \
# 6104  STA0045
#
#                                                                       name  \
# 6104  Startech charging cable 2m Thunderbolt 3 20Gb / s (compatible USB-C)
#
#                                                                                 desc  \
# 6104  Cable length 2 meters connection Thunderbolt Thunderbolt 3 to 3 for Mac and PC
#
#       price  in_stock  type short      long
# 6104  49.99         1  1325   STA  Startech

# %%
brands_df.loc[brands_df["short"] == "XSO"]
# Out:
# Empty DataFrame
# Columns: [short, long]
# Index: []

# %%
brands_df.to_csv("brands_cleaned_phase_1.csv", index=False)
